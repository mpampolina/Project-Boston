# %% [markdown]
# # Project Boston
# This notebook will attempt to break down the following questions from the 2015, 2016, and 2017 Boston marathons
#
# * What were the average finish times per age group
# * What percentage from each age group managed to BQ in the boston marathon
# * What were the pacing profiles from the top 5 athletes
# * What were the pacing profiles by gender
# * What were the pacing profiles by time
# * What percentage of runners "hit the wall" by finish time
# * How much of a slowdown did the wall have on runners by finish time

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.ticker import PercentFormatter
plt.style.use('fivethirtyeight')
color = '#334a58'

# %%
df15 = pd.read_csv('.\\data\\2015.csv', index_col='Overall')
df16 = pd.read_csv('.\\data\\2016.csv', index_col='Overall')
df17 = pd.read_csv('.\\data\\2016.csv', index_col='Overall')
# qualifying times in 2015
qtm15 = {'18-34':'3:03:58', '35-39':'3:08:58', '40-44':'3:13:58',
       '45-49':'3:23:58', '50-54':'3:28:58', '55-59':'3:38:58',
       '60-64':'3:53:58', '65-69':'4:08:58', '70-74':'4:23:58',
       '75-79':'4:38:58', '80+':'4:53:58'}
qtf15 = {'18-34':'3:33:58', '35-39':'3:38:58', '40-44':'3:43:58',
       '45-49':'3:53:58', '50-54':'3:58:58', '55-59':'4:08:58',
       '60-64':'4:23:58', '65-69':'4:38:58', '70-74':'4:53:58',
       '75-79':'5:08:58', '80+':'5:23:58'}

# %%
# remove excess columns
df15.drop(columns='Unnamed: 0', inplace = True)

# %%
df15
# Out:
#            Bib                   Name  Age M/F           City State Country  \
# Overall
# 1            3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 2            4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 3            8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 4           11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 5           10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...        ...                    ...  ...  ..            ...   ...     ...
# 26594    25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26595    31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26596    25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26597    29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26598    25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#         Citizen Unnamed: 9       5K  ...     Half      25K      30K      35K  \
# Overall                              ...
# 1           NaN        NaN  0:14:43  ...  1:04:02  1:16:07  1:32:00  1:47:59
# 2           NaN        NaN  0:14:43  ...  1:04:01  1:16:07  1:31:59  1:47:59
# 3           NaN        NaN  0:14:43  ...  1:04:02  1:16:07  1:32:00  1:47:59
# 4           NaN        NaN  0:14:43  ...  1:04:02  1:16:07  1:32:00  1:48:03
# 5           NaN        NaN  0:14:43  ...  1:04:01  1:16:07  1:32:00  1:47:59
# ...         ...        ...      ...  ...      ...      ...      ...      ...
# 26594       NaN         MI  0:50:15  ...  3:43:46  4:25:53  5:19:44  6:17:19
# 26595       NaN        NaN  0:48:36  ...  3:47:55  4:32:44  5:31:58  6:28:56
# 26596       NaN        NaN  0:53:03  ...  3:48:21  4:33:51  5:38:56  6:38:51
# 26597       NaN        NaN  0:49:04  ...  3:43:35  4:29:20  5:31:11  6:33:35
# 26598       NaN         MI  0:40:14  ...  3:40:36  4:36:06  5:43:44  6:51:31
#
#              40K     Pace Proj Time Official Time Gender Division
# Overall
# 1        2:02:39  0:04:56         -       2:09:17      1        1
# 2        2:02:42  0:04:58         -       2:09:48      2        2
# 3        2:03:01  0:04:59         -       2:10:22      3        3
# 4        2:03:47  0:05:00         -       2:10:47      4        4
# 5        2:03:27  0:05:00         -       2:10:49      5        5
# ...          ...      ...       ...           ...    ...      ...
# 26594    7:13:34  0:17:31         -       7:38:56  12015      269
# 26595    7:26:19  0:17:59         -       7:51:30  12016      270
# 26596    7:36:18  0:18:18         -       7:59:33  12017       91
# 26597    7:35:38  0:18:20         -       8:00:37  14580     2055
# 26598    7:41:28  0:18:33         -       8:06:01  14581      898
#
# [26598 rows x 23 columns]

# %%
#test
ttime = df15.loc[1, 'Official Time']
df15.loc[1, 'Official Time']
# Out:
# '2:09:17'

# %%
#test
df15['Age'].dtype
# Out:
# dtype('int64')

# %%
# function to convert a time string to a net time in minutes
def timeToMins(time):
    time = time.split(':')
    h_min = float(time[0]) * 60
    m_min = float(time[1])
    s_min = float(time[2]) / 60
    return h_min + m_min + s_min

# %%
print(timeToMins(ttime))
# Out:
# 129.28333333333333

# %%
filt = (18 <= df15['Age']) & (df15['Age'] <= 34)
df15.loc[filt]
# Out:
#            Bib                   Name  Age M/F         City State Country  \
# Overall
# 1            3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 2            4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 3            8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 4           11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 5           10          Korir, Wesley   32   M       Kitale   NaN     KEN
# ...        ...                    ...  ...  ..          ...   ...     ...
# 26550    29879          Hannon, Sarah   29   F       Quincy    MA     USA
# 26559    27458          Thomas, Jenna   26   F       Woburn    MA     USA
# 26568    26907     Lynch, Kathleen C.   26   F      Waltham    MA     USA
# 26573    29406    Dzerkacz, Charlotte   30   F      Maynard    MA     USA
# 26580    12397    Simmons, William C.   27   M    Cambridge    MA     USA
#
#         Citizen Unnamed: 9       5K  ...     Half      25K      30K      35K  \
# Overall                              ...
# 1           NaN        NaN  0:14:43  ...  1:04:02  1:16:07  1:32:00  1:47:59
# 2           NaN        NaN  0:14:43  ...  1:04:01  1:16:07  1:31:59  1:47:59
# 3           NaN        NaN  0:14:43  ...  1:04:02  1:16:07  1:32:00  1:47:59
# 4           NaN        NaN  0:14:43  ...  1:04:02  1:16:07  1:32:00  1:48:03
# 5           NaN        NaN  0:14:43  ...  1:04:01  1:16:07  1:32:00  1:47:59
# ...         ...        ...      ...  ...      ...      ...      ...      ...
# 26550       NaN        NaN  0:35:26  ...  2:41:49  3:17:48  4:04:08  4:55:03
# 26559       NaN        NaN  0:37:38  ...  2:46:43  3:27:45  4:21:50  5:04:17
# 26568       NaN        NaN  0:37:46  ...  2:44:43  3:19:30  4:10:21  5:00:21
# 26573       NaN        NaN  0:36:20  ...  2:47:32  3:23:03  4:10:10  4:59:04
# 26580       NaN        NaN  0:27:46  ...  2:29:22  3:04:22  3:52:28  4:51:29
#
#              40K     Pace Proj Time Official Time Gender Division
# Overall
# 1        2:02:39  0:04:56         -       2:09:17      1        1
# 2        2:02:42  0:04:58         -       2:09:48      2        2
# 3        2:03:01  0:04:59         -       2:10:22      3        3
# 4        2:03:47  0:05:00         -       2:10:47      4        4
# 5        2:03:27  0:05:00         -       2:10:49      5        5
# ...          ...      ...       ...           ...    ...      ...
# 26550    5:42:44  0:13:53         -       6:03:51  11996     5997
# 26559    5:46:53  0:13:57         -       6:05:26  12000     6000
# 26568    5:48:01  0:14:01         -       6:07:06  12005     6001
# 26573    5:48:10  0:14:03         -       6:08:02  12008     6003
# 26580    5:50:59  0:14:15         -       6:13:24  14570     4962
#
# [7359 rows x 23 columns]

# %%
# age categories
age_groups = {18:34, 35:39, 40:44, 45:49, 50:54, 55:59, 60:64, 65:69, 70:74, 75:79}
AgeClusters = [str(age1) + '-' + str(age2) for age1, age2 in age_groups.items()]
for index, age in enumerate(age_groups):
    filt = (age <= df15['Age']) & (df15['Age'] <= age_groups[age])
    df15.loc[filt, 'AgeCluster'] = AgeClusters[index]

# 80+ age category
AgeClusters.append('80+')
df15.loc[(80 <= df15['Age']), 'AgeCluster'] = AgeClusters[10]

# %%
age_grp = df15.groupby(['AgeCluster'])

# %%
# duplicates the column
df15['QualifyTime'] = df15['AgeCluster']

# %%
filt = df15['M/F'] == 'M'
df15.loc[filt, 'QualifyTime'] = df15['QualifyTime'].map(qtm15)
filt = df15['M/F'] == 'F'
df15.loc[filt, 'QualifyTime'] = df15['QualifyTime'].map(qtf15)

# %%
df15
# Out:
#            Bib                   Name  Age M/F           City State Country  \
# Overall
# 1            3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 2            4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 3            8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 4           11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 5           10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...        ...                    ...  ...  ..            ...   ...     ...
# 26594    25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26595    31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26596    25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26597    29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26598    25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#         Citizen Unnamed: 9       5K  ...      30K      35K      40K     Pace  \
# Overall                              ...
# 1           NaN        NaN  0:14:43  ...  1:32:00  1:47:59  2:02:39  0:04:56
# 2           NaN        NaN  0:14:43  ...  1:31:59  1:47:59  2:02:42  0:04:58
# 3           NaN        NaN  0:14:43  ...  1:32:00  1:47:59  2:03:01  0:04:59
# 4           NaN        NaN  0:14:43  ...  1:32:00  1:48:03  2:03:47  0:05:00
# 5           NaN        NaN  0:14:43  ...  1:32:00  1:47:59  2:03:27  0:05:00
# ...         ...        ...      ...  ...      ...      ...      ...      ...
# 26594       NaN         MI  0:50:15  ...  5:19:44  6:17:19  7:13:34  0:17:31
# 26595       NaN        NaN  0:48:36  ...  5:31:58  6:28:56  7:26:19  0:17:59
# 26596       NaN        NaN  0:53:03  ...  5:38:56  6:38:51  7:36:18  0:18:18
# 26597       NaN        NaN  0:49:04  ...  5:31:11  6:33:35  7:35:38  0:18:20
# 26598       NaN         MI  0:40:14  ...  5:43:44  6:51:31  7:41:28  0:18:33
#
#         Proj Time Official Time Gender Division AgeCluster QualifyTime
# Overall
# 1               -       2:09:17      1        1      18-34     3:03:58
# 2               -       2:09:48      2        2      18-34     3:03:58
# 3               -       2:10:22      3        3      18-34     3:03:58
# 4               -       2:10:47      4        4      18-34     3:03:58
# 5               -       2:10:49      5        5      18-34     3:03:58
# ...           ...           ...    ...      ...        ...         ...
# 26594           -       7:38:56  12015      269      60-64     4:23:58
# 26595           -       7:51:30  12016      270      60-64     4:23:58
# 26596           -       7:59:33  12017       91      65-69     4:38:58
# 26597           -       8:00:37  14580     2055      50-54     3:28:58
# 26598           -       8:06:01  14581      898      60-64     3:53:58
#
# [26598 rows x 25 columns]

# %%
age_grp.get_group('18-34')
# Out:
#            Bib                   Name  Age M/F         City State Country  \
# Overall
# 1            3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 2            4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 3            8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 4           11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 5           10          Korir, Wesley   32   M       Kitale   NaN     KEN
# ...        ...                    ...  ...  ..          ...   ...     ...
# 26550    29879          Hannon, Sarah   29   F       Quincy    MA     USA
# 26559    27458          Thomas, Jenna   26   F       Woburn    MA     USA
# 26568    26907     Lynch, Kathleen C.   26   F      Waltham    MA     USA
# 26573    29406    Dzerkacz, Charlotte   30   F      Maynard    MA     USA
# 26580    12397    Simmons, William C.   27   M    Cambridge    MA     USA
#
#         Citizen Unnamed: 9       5K  ...      30K      35K      40K     Pace  \
# Overall                              ...
# 1           NaN        NaN  0:14:43  ...  1:32:00  1:47:59  2:02:39  0:04:56
# 2           NaN        NaN  0:14:43  ...  1:31:59  1:47:59  2:02:42  0:04:58
# 3           NaN        NaN  0:14:43  ...  1:32:00  1:47:59  2:03:01  0:04:59
# 4           NaN        NaN  0:14:43  ...  1:32:00  1:48:03  2:03:47  0:05:00
# 5           NaN        NaN  0:14:43  ...  1:32:00  1:47:59  2:03:27  0:05:00
# ...         ...        ...      ...  ...      ...      ...      ...      ...
# 26550       NaN        NaN  0:35:26  ...  4:04:08  4:55:03  5:42:44  0:13:53
# 26559       NaN        NaN  0:37:38  ...  4:21:50  5:04:17  5:46:53  0:13:57
# 26568       NaN        NaN  0:37:46  ...  4:10:21  5:00:21  5:48:01  0:14:01
# 26573       NaN        NaN  0:36:20  ...  4:10:10  4:59:04  5:48:10  0:14:03
# 26580       NaN        NaN  0:27:46  ...  3:52:28  4:51:29  5:50:59  0:14:15
#
#         Proj Time Official Time Gender Division AgeCluster QualifyTime
# Overall
# 1               -       2:09:17      1        1      18-34     3:03:58
# 2               -       2:09:48      2        2      18-34     3:03:58
# 3               -       2:10:22      3        3      18-34     3:03:58
# 4               -       2:10:47      4        4      18-34     3:03:58
# 5               -       2:10:49      5        5      18-34     3:03:58
# ...           ...           ...    ...      ...        ...         ...
# 26550           -       6:03:51  11996     5997      18-34     3:33:58
# 26559           -       6:05:26  12000     6000      18-34     3:33:58
# 26568           -       6:07:06  12005     6001      18-34     3:33:58
# 26573           -       6:08:02  12008     6003      18-34     3:33:58
# 26580           -       6:13:24  14570     4962      18-34     3:03:58
#
# [7359 rows x 25 columns]

# %%
median_age = df15['Age'].median()

# %%
males = df15['M/F'] == 'M'
females = df15['M/F'] == 'F'

malesByAge = df15.loc[males, 'AgeCluster'].value_counts()
femalesByAge = df15.loc[females, 'AgeCluster'].value_counts()
df_Participants = pd.concat([malesByAge, femalesByAge], axis ='columns', ignore_index=True)
df_Participants.rename(columns = {0:'Male Finishers', 1:'Female Finishers'}, inplace=True)
df_Participants
# Out:
#        Male Finishers  Female Finishers
# 18-34            3215              4144
# 45-49            2485              1832
# 40-44            2109              1984
# 50-54            2055              1206
# 35-39            1749              1860
# 55-59            1498               607
# 60-64             898               270
# 65-69             403                91
# 70-74             123                20
# 75-79              36                 2
# 80+                10                 1

# %%
df_Participants.sort_index(inplace=True)

# %%
df_Participants
# Out:
#        Male Finishers  Female Finishers
# 18-34            3215              4144
# 35-39            1749              1860
# 40-44            2109              1984
# 45-49            2485              1832
# 50-54            2055              1206
# 55-59            1498               607
# 60-64             898               270
# 65-69             403                91
# 70-74             123                20
# 75-79              36                 2
# 80+                10                 1

# %%
ax = df_Participants.plot.barh(stacked=True, color=['#6fcb9f','#4d1b7b'])
ax.invert_yaxis()
ax.xaxis.tick_top()
plt.title('Boston Marathon 2015 - Participants by Age Category')
plt.ylabel('Age Categories')
plt.legend(loc='lower right')
plt.show()

# %%
df15['AgeCluster'].value_counts()
# Out:
# 18-34    7359
# 45-49    4317
# 40-44    4093
# 35-39    3609
# 50-54    3261
# 55-59    2105
# 60-64    1168
# 65-69     494
# 70-74     143
# 75-79      38
# 80+        11
# Name: AgeCluster, dtype: int64

# %%
df15['Official MTime'] = df15['Official Time'].apply(lambda x: timeToMins(x))
df15['Qualify MTime'] = df15['QualifyTime'].apply(lambda x: timeToMins(x))

# %%
age_grp['Official MTime'].agg(['median', 'mean'])
# Out:
#                 median        mean
# AgeCluster
# 18-34       209.550000  219.247556
# 35-39       211.633333  218.169142
# 40-44       217.450000  222.454349
# 45-49       220.733333  225.945923
# 50-54       224.816667  231.133717
# 55-59       231.816667  238.632494
# 60-64       244.800000  251.107277
# 65-69       260.366667  266.902429
# 70-74       275.566667  280.142308
# 75-79       282.816667  289.837281
# 80+         320.916667  317.927273

# %%
# filter by faster than BQ and gender
beatBQM = (df15['Official MTime'] < df15['Qualify MTime']) & (df15['M/F'] == 'M')
beatBQF = (df15['Official MTime'] < df15['Qualify MTime']) & (df15['M/F'] == 'F')

# group by age group and the above filters
BQMage_grp = df15.loc[beatBQM].groupby(['AgeCluster'])
BQFage_grp = df15.loc[beatBQF].groupby(['AgeCluster'])

# %%
df15.loc[beatBQM, 'Official MTime'].median()
# Out:
# 185.45833333333331

# %%
df15.loc[beatBQF]
# Out:
#            Bib                   Name  Age M/F             City State Country  \
# Overall
# 31         F11       Rotich, Caroline   30   F        Nyahururu   NaN     KEN
# 32          F2           Dibaba, Mare   25   F             Shoa   NaN     ETH
# 34          F1         Deba, Buzunesh   27   F             Arsi   NaN     ETH
# 40         F10        Linden, Desiree   31   F  Rochester Mills    MI     USA
# 44          F8         Cherop, Sharon   31   F         Marakwet   NaN     KEN
# ...        ...                    ...  ...  ..              ...   ...     ...
# 24198    25505  Tattersall, Theresa M   71   F      N Attleboro    MA     USA
# 24303    25410           Ashton, Rona   70   F         Ridgeway    ON     CAN
# 24380    25473     Bardin, Dorothy A.   75   F         New York    NY     USA
# 24501    25480       Spradlin, Hiroko   71   F       Buena Park    CA     USA
# 24549    25520        Phipps, Mariana   70   F            Omaha    NE     USA
#
#         Citizen Unnamed: 9       5K  ...      40K     Pace Proj Time  \
# Overall                              ...
# 31          NaN        NaN  0:16:59  ...  2:17:30  0:05:32         -
# 32          NaN        NaN  0:16:58  ...  2:17:30  0:05:32         -
# 34          NaN        NaN  0:16:57  ...  2:17:30  0:05:33         -
# 40          NaN        NaN  0:17:00  ...  2:17:51  0:05:34         -
# 44          NaN        NaN  0:16:59  ...  2:18:02  0:05:35         -
# ...         ...        ...      ...  ...      ...      ...       ...
# 24198       NaN        NaN  0:29:58  ...  4:29:07  0:10:55         -
# 24303       NaN        NaN  0:32:01  ...  4:31:50  0:10:59         -
# 24380       NaN        NaN  0:31:41  ...  4:32:55  0:11:02         -
# 24501       NaN        NaN  0:32:25  ...  4:35:54  0:11:07         -
# 24549       NaN        NaN  0:30:41  ...  4:36:47  0:11:10         -
#
#         Official Time Gender Division AgeCluster QualifyTime Official MTime  \
# Overall
# 31            2:24:55      1        1      18-34     3:33:58     144.916667
# 32            2:24:59      2        2      18-34     3:33:58     144.983333
# 34            2:25:09      3        3      18-34     3:33:58     145.150000
# 40            2:25:39      4        4      18-34     3:33:58     145.650000
# 44            2:26:05      5        5      18-34     3:33:58     146.083333
# ...               ...    ...      ...        ...         ...            ...
# 24198         4:45:53  10647        8      70-74     4:53:58     285.883333
# 24303         4:47:37  10710        9      70-74     4:53:58     287.616667
# 24380         4:49:12  10750        2      75-79     5:08:58     289.200000
# 24501         4:51:27  10825       10      70-74     4:53:58     291.450000
# 24549         4:52:27  10855       11      70-74     4:53:58     292.450000
#
#         Qualify MTime
# Overall
# 31         213.966667
# 32         213.966667
# 34         213.966667
# 40         213.966667
# 44         213.966667
# ...               ...
# 24198      293.966667
# 24303      293.966667
# 24380      308.966667
# 24501      293.966667
# 24549      293.966667
#
# [5470 rows x 27 columns]

# %%
# total number of finishers
tot = age_grp['Name'].count()

# number of male BQ finishers
BQM = BQMage_grp['Name'].count()

# number of female BQ finishers
BQF = BQFage_grp['Name'].count()

# new dataframe with all the finisher numbers
# concatenated along the column axis
# ignore "Name" index
df_MF = pd.concat([BQM, BQF, tot], axis='columns', ignore_index=True)

# rename ignore_index default column names
df_MF.rename(columns = {0:'MaleBQ', 1:'FemaleBQ', 2:'TotalFinishers'}, inplace=True)

# create columns for percentage of BQers from each gender
df_MF['MaleBQPct'] = (df_MF['MaleBQ']/df_MF['TotalFinishers'])
df_MF['FemaleBQPct'] = (df_MF['FemaleBQ']/df_MF['TotalFinishers'])

# new dataframe for percentage series 
df_MFPct = pd.concat([df_MF['MaleBQPct'],  df_MF['FemaleBQPct']], axis='columns')

# %%
df_MF
# Out:
#        MaleBQ  FemaleBQ  TotalFinishers  MaleBQPct  FemaleBQPct
# 18-34    1627    1772.0            7359   0.221090     0.240794
# 35-39     860     862.0            3609   0.238293     0.238847
# 40-44     954     851.0            4093   0.233081     0.207916
# 45-49    1186     905.0            4317   0.274728     0.209636
# 50-54     857     595.0            3261   0.262803     0.182459
# 55-59     630     291.0            2105   0.299287     0.138242
# 60-64     368     140.0            1168   0.315068     0.119863
# 65-69     171      41.0             494   0.346154     0.082996
# 70-74      47      11.0             143   0.328671     0.076923
# 75-79      15       2.0              38   0.394737     0.052632
# 80+         3       NaN              11   0.272727          NaN

# %%
df_MFPct
# Out:
#        MaleBQPct  FemaleBQPct
# 18-34   0.221090     0.240794
# 35-39   0.238293     0.238847
# 40-44   0.233081     0.207916
# 45-49   0.274728     0.209636
# 50-54   0.262803     0.182459
# 55-59   0.299287     0.138242
# 60-64   0.315068     0.119863
# 65-69   0.346154     0.082996
# 70-74   0.328671     0.076923
# 75-79   0.394737     0.052632
# 80+     0.272727          NaN

# %%
ax = df_MFPct.plot.area(color=['#6fcb9f','#4d1b7b'])
plt.legend()
plt.title('Boston Marathon 2015 - Proportion of runners \n scoring BQ times or faster')
# xmax refers to the multiplication factor in the % equation
ax.yaxis.set_major_formatter(PercentFormatter(xmax=1))
plt.xlabel('age groups')
plt.show()
